# %%
V = 4
maxx = 999

def FWA(graph):
    for k in range(V):
        for i in range(V):
            for j in range(V):
                    graph[i][j] = min(graph[i][j],graph[i][k]+graph[k][j])

        
    for i in range(V):
        for j in range(V):
            print(graph[i][j],end=' ')
        print('')
        
        
    for i in range(V):
        for j in range(V):
            print('\nDistance from',i,'to',j,'is = ',graph[i][j],'\n')
            

graph = [[0, 3, maxx, 5],
         [2, 0, maxx, 4],
         [maxx, 1, 0, maxx],
         [maxx, maxx, 2, 0]]
FWA(graph)
# Out:
# 0 3 7 5
# 2 0 6 4
# 3 1 0 5
# 5 3 2 0
#
# Distance from 0 to 0 is =  0
#
#
# Distance from 0 to 1 is =  3
#
#
# Distance from 0 to 2 is =  7
#
#
# Distance from 0 to 3 is =  5
#
#
# Distance from 1 to 0 is =  2
#
#
# Distance from 1 to 1 is =  0
#
#
# Distance from 1 to 2 is =  6
#
#
# Distance from 1 to 3 is =  4
#
#
# Distance from 2 to 0 is =  3
#
#
# Distance from 2 to 1 is =  1
#
#
# Distance from 2 to 2 is =  0
#
#
# Distance from 2 to 3 is =  5
#
#
# Distance from 3 to 0 is =  5
#
#
# Distance from 3 to 1 is =  3
#
#
# Distance from 3 to 2 is =  2
#
#
# Distance from 3 to 3 is =  0

# %%
V = 4
maxx = 999

def FWA(graph):
    for k in range(V):
        for i in range(V):
            for j in range(V):
                if(graph[i][j] > graph[i][k]+graph[k][j]):
                    graph[i][j] = min(graph[i][j],graph[i][k]+graph[k][j])
        if (k ==0):
            display(graph,k)
        if (k ==1):
            display(graph,k)
        if (k ==2):
            display(graph,k)
        if (k ==3):
            display(graph,k)
                    

def display(graph,k):   
    print('***** k = ',k,'\n')
    for i in range(V):
        for j in range(V):
            if(graph[i][j]==maxx):
                print('M',end=' ')
            else:
                print(graph[i][j],end=' ')
        print('')
    print('\n')       

graph = [[0, 3, maxx, 5],
         [2, 0, maxx, 4],
         [maxx, 1, 0, maxx],
         [maxx, maxx, 2, 0]]
FWA(graph)
# Out:
# ***** k =  0
#
# 0 3 M 5
# 2 0 M 4
# M 1 0 M
# M M 2 0
#
#
# ***** k =  1
#
# 0 3 M 5
# 2 0 M 4
# 3 1 0 5
# M M 2 0
#
#
# ***** k =  2
#
# 0 3 M 5
# 2 0 M 4
# 3 1 0 5
# 5 3 2 0
#
#
# ***** k =  3
#
# 0 3 7 5
# 2 0 6 4
# 3 1 0 5
# 5 3 2 0
